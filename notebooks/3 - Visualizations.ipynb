# %%
# Importing libraries
from quickda.explore_data import *
from quickda.clean_data import *
from quickda.explore_numeric import *
from quickda.explore_categoric import *
from quickda.explore_numeric_categoric import *
from quickda.explore_time_series import *

import matplotlib.pyplot as plt

import pandas as pd

import os

# %%
parent_folder = os.path.dirname(os.getcwd())

# %%
aviation_data_path = os.path.join(
    parent_folder, 'data', 'clean_aviation_data_2.csv')
data = pd.read_csv(aviation_data_path, encoding='latin-1')

viz_aviation_data_path = os.path.join(
    parent_folder, 'data', 'viz_aviation_data.csv')
data_2 = pd.read_csv(viz_aviation_data_path, encoding='latin-1')


encod_aviation_data_path = os.path.join(
    parent_folder, 'data', 'encoded_aviation_data_3.csv')
data_3 = pd.read_csv(encod_aviation_data_path, encoding='latin-1')

# %%
data_2['make'].value_counts()
# Out:
# CESSNA           16889
# PIPER             9134
# BEECH             3167
# BELL              1489
# GRUMMAN            945
#                  ...
# HALL-CAVALIER        1
# HALLAM               1
# HALLETT              1
# HALLQUIST            1
# ZWART                1
# Name: make, Length: 3214, dtype: int64

# %%
len(data_2['make'].unique())
# Out:
# 3214

# %%
data_3[data_3.dtypes[(data_3.dtypes=="float64")|(data_3.dtypes=="int64")]
                        .index.values].hist(figsize=[11,11])
# Out:
# array([[<Axes: title={'center': 'Unnamed: 0'}>,
#         <Axes: title={'center': 'target'}>,
#         <Axes: title={'center': 'location'}>,
#         <Axes: title={'center': 'aircraft_damage'}>],
#        [<Axes: title={'center': 'make'}>,
#         <Axes: title={'center': 'model'}>,
#         <Axes: title={'center': 'number_of_engines'}>,
#         <Axes: title={'center': 'engine_type'}>],
#        [<Axes: title={'center': 'weather_conditions'}>,
#         <Axes: title={'center': 'phase_of_flight'}>,
#         <Axes: title={'center': 'Year'}>,
#         <Axes: title={'center': 'Month'}>],
#        [<Axes: title={'center': 'Day'}>,
#         <Axes: title={'center': 'injuries'}>,
#         <Axes: title={'center': 'pax_onboard'}>,
#         <Axes: title={'center': 'fatality_percentage'}>],
#        [<Axes: title={'center': 'survived'}>,
#         <Axes: title={'center': 'amateur_built'}>, <Axes: >, <Axes: >]],
#       dtype=object)

# %%
data_2[data_2.dtypes[(data_2.dtypes=="float64")|(data_2.dtypes=="int64")]
                        .index.values].hist(figsize=[11,11])
# Out:
# array([[<Axes: title={'center': 'Unnamed: 0'}>,
#         <Axes: title={'center': 'number_of_engines'}>,
#         <Axes: title={'center': 'Year'}>],
#        [<Axes: title={'center': 'Month'}>,
#         <Axes: title={'center': 'Day'}>,
#         <Axes: title={'center': 'injuries'}>],
#        [<Axes: title={'center': 'pax_onboard'}>,
#         <Axes: title={'center': 'fatality_percentage'}>,
#         <Axes: title={'center': 'survived'}>]], dtype=object)

# %%
#plot target variables 


y = "target"
ax = data_2[y].value_counts().sort_values().plot(kind="barh")
totals= []
for i in ax.patches:
    totals.append(i.get_width())
total = sum(totals)
for i in ax.patches:
     ax.text(i.get_width()+.3, i.get_y()+.20, 
     str(round((i.get_width()/total)*100, 2))+'%', 
     fontsize=10, color='black')
ax.grid(axis="x")
plt.suptitle(y, fontsize=20)
plt.show()

plt_save_path = os.path.join(
    parent_folder, 'imgs', 'target_bar.png')

plt.savefig(plt_save_path)

# %%
#Up to 300 passengers survived and about 550 didn’t, in other words the survival rate (or the population mean) is 38%.

# %%
eda_num(data_3)
# Out:
# Outlier Analysis - Boxplot
# Distribution Analysis - Histogram

# %%
eda_num(data_2)
# Out:
# Outlier Analysis - Boxplot
# Distribution Analysis - Histogram

# %%
#select which column to visualize
eda_num(data[['column_1', 'columns_2', 'column_n']])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[16], line 2
#       1 #select which column to visualize
# ----> 2 eda_num(data[['column_1', 'columns_2', 'column_n']])
#
# File c:\Users\Makara PC\.conda\envs\ml-practice\Lib\site-packages\pandas\core\frame.py:3813, in DataFrame.__getitem__(self, key)
#    3811     if is_iterator(key):
#    3812         key = list(key)
# -> 3813     indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    3815 # take() does not accept boolean indexers
#    3816 if getattr(indexer, "dtype", None) == bool:
#
# File c:\Users\Makara PC\.conda\envs\ml-practice\Lib\site-packages\pandas\core\indexes\base.py:6070, in Index._get_indexer_strict(self, key, axis_name)
#    6067 else:
#    6068     keyarr, indexer, new_indexer = self._reindex_non_unique(keyarr)
# -> 6070 self._raise_if_missing(keyarr, indexer, axis_name)
#    6072 keyarr = self.take(indexer)
#    6073 if isinstance(key, Index):
#    6074     # GH 42790 - Preserve name from an Index
#
# File c:\Users\Makara PC\.conda\envs\ml-practice\Lib\site-packages\pandas\core\indexes\base.py:6130, in Index._raise_if_missing(self, key, indexer, axis_name)
#    6128     if use_interval_msg:
#    6129         key = list(key)
# -> 6130     raise KeyError(f"None of [{key}] are in the [{axis_name}]")
#    6132 not_found = list(ensure_index(key)[missing_mask.nonzero()[0]].unique())
#    6133 raise KeyError(f"{not_found} not in index")
#
# KeyError: "None of [Index(['column_1', 'columns_2', 'column_n'], dtype='object')] are in the [columns]"

# %%
eda_num(data_3, method="correlation")
# Out:
# Correlation Analysis - Heatmap
# c:\Users\Makara PC\.conda\envs\ml-practice\Lib\site-packages\quickda\explore_numeric.py:30: FutureWarning:
#
# this method is deprecated in favour of `Styler.format(precision=..)`
# <style type="text/css">
# #T_a8681_row0_col0, #T_a8681_row1_col1, #T_a8681_row2_col2, #T_a8681_row3_col3, #T_a8681_row4_col4, #T_a8681_row5_col5, #T_a8681_row6_col6, #T_a8681_row7_col7, #T_a8681_row8_col8, #T_a8681_row9_col9, #T_a8681_row10_col10, #T_a8681_row11_col11, #T_a8681_row12_col12, #T_a8681_row13_col13, #T_a8681_row14_col14, #T_a8681_row15_col15, #T_a8681_row16_col16, #T_a8681_row17_col17 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_a8681_row0_col1, #T_a8681_row1_col0, #T_a8681_row1_col11, #T_a8681_row3_col14, #T_a8681_row5_col8, #T_a8681_row6_col11, #T_a8681_row7_col8, #T_a8681_row7_col15, #T_a8681_row8_col5, #T_a8681_row8_col7, #T_a8681_row11_col1, #T_a8681_row11_col6, #T_a8681_row11_col12, #T_a8681_row12_col11, #T_a8681_row14_col3, #T_a8681_row15_col7 {
#   background-color: #d8dce2;
#   color: #000000;
# }
# #T_a8681_row0_col2, #T_a8681_row0_col11, #T_a8681_row1_col2, #T_a8681_row1_col7, #T_a8681_row1_col12, #T_a8681_row2_col0, #T_a8681_row2_col1, #T_a8681_row2_col3, #T_a8681_row2_col4, #T_a8681_row2_col5, #T_a8681_row2_col8, #T_a8681_row3_col2, #T_a8681_row4_col2, #T_a8681_row4_col9, #T_a8681_row5_col2, #T_a8681_row7_col1, #T_a8681_row8_col2, #T_a8681_row8_col12, #T_a8681_row9_col4, #T_a8681_row9_col16, #T_a8681_row10_col13, #T_a8681_row11_col0, #T_a8681_row11_col13, #T_a8681_row12_col1, #T_a8681_row12_col8, #T_a8681_row13_col10, #T_a8681_row13_col11, #T_a8681_row16_col9 {
#   background-color: #dbdcde;
#   color: #000000;
# }
# #T_a8681_row0_col3, #T_a8681_row0_col13, #T_a8681_row1_col10, #T_a8681_row2_col7, #T_a8681_row2_col11, #T_a8681_row3_col0, #T_a8681_row3_col11, #T_a8681_row5_col9, #T_a8681_row5_col12, #T_a8681_row7_col2, #T_a8681_row7_col12, #T_a8681_row9_col5, #T_a8681_row9_col10, #T_a8681_row10_col1, #T_a8681_row10_col9, #T_a8681_row11_col2, #T_a8681_row11_col3, #T_a8681_row12_col5, #T_a8681_row12_col7, #T_a8681_row13_col0, #T_a8681_row13_col17, #T_a8681_row17_col13 {
#   background-color: #d9dce1;
#   color: #000000;
# }
# #T_a8681_row0_col4, #T_a8681_row4_col0 {
#   background-color: #c0282f;
#   color: #f1f1f1;
# }
# #T_a8681_row0_col5, #T_a8681_row5_col0 {
#   background-color: #f39577;
#   color: #000000;
# }
# #T_a8681_row0_col6, #T_a8681_row0_col10, #T_a8681_row3_col17, #T_a8681_row6_col0, #T_a8681_row10_col0, #T_a8681_row17_col3 {
#   background-color: #d2dbe8;
#   color: #000000;
# }
# #T_a8681_row0_col7, #T_a8681_row0_col16, #T_a8681_row7_col0, #T_a8681_row9_col15, #T_a8681_row15_col9, #T_a8681_row16_col0 {
#   background-color: #cfdaea;
#   color: #000000;
# }
# #T
col8 {
#   background-color: #d6dce4;
#   color: #000000;
# }
# #T_a8681_row1_col8, #T_a8681_row8_col1 {
#   background-color: #f6bfa6;
#   color: #000000;
# }
# #T_a8681_row1_col9, #T_a8681_row5_col15, #T_a8681_row8_col17, #T_a8681_row9_col1, #T_a8681_row15_col5, #T_a8681_row17_col8 {
#   background-color: #e4d9d2;
#   color: #000000;
# }
# #T_a8681_row1_col13, #T_a8681_row13_col1 {
#   background-color: #bad0f8;
#   color: #000000;
# }
# #T_a8681_row1_col14, #T_a8681_row5_col7, #T_a8681_row7_col5, #T_a8681_row7_col10, #T_a8681_row10_col7, #T_a8681_row14_col1 {
#   background-color: #e0dbd8;
#   color: #000000;
# }
# #T_a8681_row1_col15, #T_a8681_row15_col1 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_a8681_row1_col16, #T_a8681_row16_col1 {
#   background-color: #e5d8d1;
#   color: #000000;
# }
# #T_a8681_row1_col17, #T_a8681_row17_col1 {
#   background-color: #cedaeb;
#   color: #000000;
# }
# #T_a8681_row2_col6, #T_a8681_row2_col14, #T_a8681_row2_col16, #T_a8681_row3_col4, #T_a8681_row3_col7, #T_a8681_row4_col3, #T_a8681_row4_col7, #T_a8681_row6_col2, #T_a8681_row7_col3, #T_a8681_row7_col4, #T_a8681_row14_col2, #T_a8681_row16_col2 {
#   background-color: #d7dce3;
#   color: #000000;
# }
# #T_a8681_row3_col8, #T_a8681_row8_col3 {
#   background-color: #f4c5ad;
#   color: #000000;
# }
# #T_a8681_row3_col9, #T_a8681_row9_col3 {
#   background-color: #e3d9d3;
#   color: #000000;
# }
# #T_a8681_row3_col10, #T_a8681_row7_col13, #T_a8681_row10_col3, #T_a8681_row13_col7 {
#   background-color: #e1dad6;
#   color: #000000;
# }
# #T_a8681_row3_col13, #T_a8681_row13_col3 {
#   background-color: #bed2f6;
#   color: #000000;
# }
# #T_a8681_row3_col15, #T_a8681_row15_col3 {
#   background-color: #6f92f3;
#   color: #f1f1f1;
# }
# #T_a8681_row4_col5, #T_a8681_row5_col4 {
#   background-color: #ee8468;
#   color: #f1f1f1;
# }
# #T_a8681_row4_col14, #T_a8681_row14_col4, #T_a8681_row16_col17, #T_a8681_row17_col16 {
#   background-color: #d4dbe6;
#   color: #000000;
# }
# #T_a8681_row4_col15, #T_a8681_row15_col4 {
#   background-color: #dfdbd9;
#   color: #000000;
# }
# #T_a8681_row4_col16, #T_a8681_row14_col15, #T_a8681_row15_col14, #T_a8681_row16_col4 {
#   background-color: #d3dbe7;
#   color: #000000;
# }
# #T_a8681_row4_col17, #T_a8681_row13_col15, #T_a8681_row15_col13, #T_a8681_row17_col4 {
#   background-color: #efcfbf;
#   color: #000000;
# }
# #T_a8681_row5_col10, #T_a8681_row6_col15, #T_a8681_row10_col5, #T_a8681_row15_col6 {
#   background-color: #dedcdb;
#   color: #000000;
# }
# #T_a8681_row5_col17, #T_a8681_row17_col5 {
#   background-color: #f3c8b2;
#   color: #000000;
# }
# #T_a8681_row6_col8, #T_a8681_row8_col6 {
#   background-color: #c6d6f1;
#   color: #000000;
# }
# #T_a8681_row6_col13, #T_a8681_row13_col6 {
#   background-color: #ead5c9;
#   color: #000000;
# }
# #T_a8681_row6_col14, #T_a8681_row14_col6 {

# %%
data_2.columns
# Out:
# Index(['Unnamed: 0', 'target', 'location', 'aircraft_damage', 'make', 'model',
#        'number_of_engines', 'engine_type', 'weather_conditions',
#        'phase_of_flight', 'Year', 'Month', 'Day', 'injuries', 'pax_onboard',
#        'fatality_percentage', 'survived', 'amateur_built'],
#       dtype='object')

# %%
eda_cat(data, x='aircraft_damage')
# Out:
# Bar Plot of aircraft_damage
# Summary of aircraft_damage
#              count  relative_pct
# Substantial  34341          0.71
# Destroyed    12901          0.27
# Minor         1419          0.03

# %%
eda_cat(data_2, x='engine_type', y='target')
# Out:
# Bar Plot of engine_type with respect to target
# Crosstabulation of engine_type across target
# target         Fatal  Non-Fatal
# engine_type
# Reciprocating   0.19       0.81
# Turbo Shaft     0.22       0.78
# Turbo Prop      0.22       0.78
# Unknown         0.12       0.88
# Turbo Fan       0.08       0.92
# Turbo Jet       0.17       0.83

# %%
eda_cat(data_2, x='phase_of_flight', y='target')
# Out:
# Bar Plot of phase_of_flight with respect to target
# Crosstabulation of phase_of_flight across target
# target           Fatal  Non-Fatal
# phase_of_flight
# LANDING           0.02       0.98
# TAKEOFF           0.14       0.86
# CRUISE            0.27       0.73
# MANEUVERING       0.38       0.62
# APPROACH          0.24       0.76
# CLIMB             0.30       0.70
# TAXI              0.02       0.98
# DESCENT           0.24       0.76
# GO-AROUND         0.19       0.81
# STANDING          0.10       0.90
# UNKNOWN           0.78       0.22
# OTHER             0.42       0.58

# %%
eda_cat(data_2, x='aircraft_damage', y='target')
# Out:
# Bar Plot of aircraft_damage with respect to target
# Crosstabulation of aircraft_damage across target
# target           Fatal  Non-Fatal
# aircraft_damage
# Substantial       0.03       0.97
# Destroyed         0.61       0.39
# Minor             0.05       0.95

# %%
eda_numcat(data_3, 'target', method="pps")
# Out:
# Feature Importance in the prediction of target

# %%
eda_numcat(data_2, x='target', y='fatality_percentage', 
           hue=None, method='relationship')
# Out:
# Scatterplot of target versus fatality_percentage

# %%
eda_numcat(data_3, x='Year', y='fatality_percentage', 
           hue=None, method='relationship')
# Out:
# Scatterplot of Year versus fatality_percentage

# %%
data_3.columns
# Out:
# Index(['Unnamed: 0', 'target', 'location', 'aircraft_damage', 'make', 'model',
#        'number_of_engines', 'engine_type', 'weather_conditions',
#        'phase_of_flight', 'Year', 'Month', 'Day', 'injuries', 'pax_onboard',
#        'fatality_percentage', 'survived', 'amateur_built'],
#       dtype='object')

# %%
test = eda_timeseries(data_2, x='year', y='fatality_percentage')
# Out:
# Distribution - Time Series Data
# 'year'

# %%
data_2.head()
# Out:
#    Unnamed: 0     target       location aircraft_damage     make  \
# 0           0  Non-Fatal    CAMBRIA, NY       Destroyed  Unknown
# 1           1  Non-Fatal  MCWHORTER, KY       Destroyed  Unknown
# 2           2      Fatal  FREDERICK, MD       Destroyed  Unknown
# 3           3  Non-Fatal    VENTURA, CA       Destroyed  Unknown
# 4           4  Non-Fatal     SIDNEY, NE     Substantial  Unknown
#
#             model  number_of_engines    engine_type weather_conditions  \
# 0              64                1.0  Reciprocating                VMC
# 1            KR-2                1.0  Reciprocating                VMC
# 2       WINDWAGON                1.0  Reciprocating                VMC
# 3  MIDGET MUSTANG                1.0  Reciprocating                VMC
# 4         SKYBOLT                1.0  Reciprocating                VMC
#
#   phase_of_flight  Year  Month  Day  injuries  pax_onboard  \
# 0           CLIMB  1982      6   13       1.0          1.0
# 1          CRUISE  1982      7    1       2.0          2.0
# 2        APPROACH  1982      7   16       1.0          1.0
# 3     MANEUVERING  1982      8   21       0.0          1.0
# 4         LANDING  1982      8   24       0.0          1.0
#
#    fatality_percentage  survived amateur_built
# 0                  0.0       1.0            No
# 1                  0.0       2.0           Yes
# 2                100.0       0.0           Yes
# 3                  0.0       1.0           Yes
# 4                  0.0       1.0           Yes

# %%
data_2.groupby('make')['fatality_percentage'].count().nlargest(10).plot(kind='pie')
# Out:
# <Axes: ylabel='fatality_percentage'>
